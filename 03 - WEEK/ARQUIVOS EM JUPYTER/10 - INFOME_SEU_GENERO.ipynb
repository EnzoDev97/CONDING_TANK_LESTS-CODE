# %%
genero = ''

while genero!= 'F' and genero!='M' and genero!='O':
    print('INFORMAÇÃO INVALIDA')
    genero = input('INFORME SEU GÊNERO: (F/M/O): ')
    
print('-'*60)
print('\n')
print('O GÊNERO INFORMADO  FOI : {}'.format(genero))
# Out:
# INFORMAÇÃO INVALIDA
# ------------------------------------------------------------
#
#
# O GÊNERO INFORMADO FOI : M
